# %%
import pandas as pd
from nbgrader.api import Gradebook
# Create the connection to the database
with Gradebook('sqlite:///gradebook.db') as gb:
    path_of_file_holding_student_ids =  'student_ids.txt'
    # read the txt file
    with open(path_of_file_holding_student_ids) as f:
        # extract ids in a list.
        student_ids = [word.strip() for line in f.readlines() for          word in line.split(',') if word.strip()]
        # populate database with ids
        for _id in student_ids:
            print(_id)
            gb.add_student(_id)
# Out:
# bart
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: student.id
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\nbgrader\api.py:1423, in Gradebook.add_student(self, student_id, **kwargs)
#    1422 try:
# -> 1423     self.db.commit()
#    1424 except (IntegrityError, FlushError, StatementError) as e:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\scoping.py:554, in scoped_session.commit(self)
#     516 r"""Flush pending changes and commit the current transaction.
#     517
#     518 .. container:: class_bases
#    (...)
#     551
#     552 """  # noqa: E501
# --> 554 return self._proxied.commit()
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\session.py:1923, in Session.commit(self)
#    1921     trans = self._autobegin_t()
# -> 1923 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\session.py:1239, in SessionTransaction.commit(self, _to_root)
#    1238     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1239         self._prepare_impl()
#    1241 if self._parent is None or self.nested:
#
# File <string>:2, in _prepare_impl(self)
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\state_changes.py:139, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     138 try:
# --> 139     ret_value = fn(self, *arg, **kw)
#     140 except:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\session.py:1214, in SessionTransaction._prepare_impl(self)
#    1213         break
# -> 1214     self.session.flush()
#    1215 else:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\session.py:4179, in Session.flush(self, objects)
#    4178     self._flushing = True
# -> 4179     self._flush(objects)
#    4180 finally:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\session.py:4315, in Session._flush(self, objects)
#    4314 with util.safe_reraise():
# -> 4315     transaction.rollback(_capture_exception=True)
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\util\langhelpers.py:146, in safe_reraise.__exit__(self, type_, value, traceback)
#     145     self._exc_info = None  # remove potential circular references
# --> 146     raise exc_value.with_traceback(exc_tb)
#     147 else:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\session.py:4275, in Session._flush(self, objects)
#    4274 try:
# -> 4275     flush_context.execute()
#    4276 finally:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\unitofwork.py:466, in UOWTransaction.execute(self)
#     465 for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466     rec.execute(self)
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\orm\persistence.py:1043, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1041 multiparams = [rec[2] for rec in records]
# -> 1043 result = connection.execute(
#    1044     statement, multiparams, execution_options=execution_options
#    1045 )
#    1046 if bookkeeping:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\sql\elements.py:516, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     515         assert isinstance(self, Executable)
# --> 516     return connection._execute_clauseelement(
#     517         self, distilled_params, execution_options
#     518     )
#     519 else:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\base.py:1635, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1627 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1628     dialect=dialect,
#    1629     compiled_cache=compiled_cache,
#    (...)
#    1633     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1634 )
# -> 1635 ret = self._execute_context(
#    1636     dialect,
#    1637     dialect.execution_ctx_cls._init_compiled,
#    1638     compiled_sql,
#    1639     distilled_parameters,
#    1640     execution_options,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     elem,
#    1644     extracted_params,
#    1645     cache_hit=cache_hit,
#    1646 )
#    1647 if has_events:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\sqlalchemy\engine\default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: student.id
# [SQL: INSERT INTO student (id, first_name, last_name, email, lms_user_id) VALUES (?, ?, ?, ?, ?)]
# [parameters: ('bart', None, None, None, None)]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)
#
# During handling of the above exception, another exception occurred:
#
# InvalidEntry                              Traceback (most recent call last)
# Cell In[6], line 13
#      11 for _id in student_ids:
#      12     print(_id)
# ---> 13     gb.add_student(_id)
#
# File ~\anaconda3\envs\nbgrader_env\lib\site-packages\nbgrader\api.py:1427, in Gradebook.add_student(self, student_id, **kwargs)
#    1425     app_log.exception("Rolling back session due to database error %s" % e)
#    1426     self.db.rollback()
# -> 1427     raise InvalidEntry(*e.args)
#    1429 return student
#
# InvalidEntry: (sqlite3.IntegrityError) UNIQUE constraint failed: student.id

# %%
with Gradebook('sqlite:///gradebook.db') as gb:
    print(gb)
# Out:
# <nbgrader.api.Gradebook object at 0x000002558A186BB0>
